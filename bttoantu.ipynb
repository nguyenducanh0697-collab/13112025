# %%
#W2A4:
a1,b1,c1,a2,b2,a3=map(float,input().split())
diem_trung_binh= ((a1+b1+c1)+(a2+b2)*2+a3*3)/10
print(diem_trung_binh)
# Out:
# 5.2

# %%
#W2A6:
chu_cai_thuong=input('nhap vao chu cai thuong: ')
maunicode=ord(chu_cai_thuong)
print('ma unicode la: ', maunicode)
chu_cai_hoa= chu_cai_thuong.upper()
print('chu cai hoa la: ', chu_cai_hoa)
# Out:
# ma unicode la:  116
# chu cai hoa la:  T

# %%
#W2A18:
print('### ## ### ###')
print(' #  # # #   #')
print(' #  # # #   # ')
print(' #  # # #   #')
print(' #  ##  #   # ')
# Out:
# ### ## ### ###
#  #  # # #   #
#  #  # # #   #
#  #  # # #   #
#  #  ##  #   #

# %%
#W2A21:
for i in range(10):
    print('Hello,world')
# Out:
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world
# Hello,world

# %%
#W2A20:
print('Cac thang trong nam: ')
print('January')
print('February')
print('March')
print('April')
print('May')
print('June')
print('July')
print('August')
print('September')
print('October')
print('November')
print('December')
# Out:
# Cac thang trong nam:
# January
# February
# March
# April
# May
# June
# July
# August
# September
# October
# November
# December

# %%
#W2A1:
print('Hello World')
# Out:
# Hello World

# %%
#W2A2:
a= input('nhap ten: ')
print('xin chao, ',a)
# Out:
# xin chao,  duc anh

# %%
#W2A3:
a=int(input('nhap a: '))
b=int(input('nhap b: '))
print('tong a va b la: ', a+b)
print('hieu a tru b la: ', a-b)
print('tich a va b la: ', a*b)
if b==0:
    print('khong the chia cho 0')
else:
    print('phan nguyen cua phep chia a cho b la: ', a//b)
    print('phan du cua phep chia a cho b la: ', a%b)
    print('ket qua chia thuc cua a cho b la: ', round(a/b, 2))
# Out:
# tong a va b la:  13
# hieu a tru b la:  7
# tich a va b la:  30
# phan nguyen cua phep chia a cho b la:  3
# phan du cua phep chia a cho b la:  1
# ket qua chia thuc cua a cho b la:  3.33

# %%
#W2A5:
a,b=map(int,input('nhap co so a va so mu b cach nhau bang dau cach: ').split())
print('ket qua a mu b hay a^b la: ', a**b)
# Out:
# ket qua a mu b hay a^b la:  8

# %%
#W2A7:
A=((13**2)*3)+5
B=13**2*3+5
print(A)
print(B)
# Out:
# 512
# 512

# %%
#W2A8:
C=float(input('nhap do Celcius: '))
F=9/5*C+32
print('nhiet do Fahrenheit tuong ung la: ', round(F,2))
# Out:
# nhiet do Fahrenheit tuong ung la:  97.45

# %%
#W2A9:
gia_tien=float(input('nhap gia tien (USD): '))
print('tong tien phai tra la: ', round(((gia_tien*30)/100+(gia_tien*10)/100+10),2), 'USD')
# Out:
# tong tien phai tra la:  28.27 USD

# %%
#W2A10:
ten1=input('nhap ten 1: ')
ten2=input('nhap ten 2: ')
ten3=input('nhap ten 3: ')
print(f"Hi {ten3}, {ten2} and {ten1}")
# Out:
# Hi helen, alice and bob

# %%
#W2A11:
gio=float(input('nhap so gio: '))
phut=float(input('nhap so phut: '))
tong_giay= gio*3600 + phut*60
print('gio va phut duoc chuyen sang giay la: ', tong_giay)
# Out:
# gio va phut duoc chuyen sang giay la:  5400.0

# %%
#W2A12:
n=float(input('nhap do dai canh rubik: '))
miengdan= 6*n*n
print('so mieng dan la: ',miengdan)
# Out:
# so mieng dan la:  6.0

# %%
#W2A13:
a=int(input('nhap so nguyen duong a: '))
b=int(input('nhap so nguyen duong b: '))
hang_don_vi_tich_a_va_b=(a*b)%10
print('hang don vi cua tich a va b la: ',hang_don_vi_tich_a_va_b)
# Out:
# hang don vi cua tich a va b la:  5

# %%
#W2A14:
a,b=map(int,input('nhap a va b: ').split())
a=a+b 
b=a-b 
a=a-b 
print('gia tri hoan doi la: ',a,b)
# Out:
# gia tri hoan doi la:  67 45

# %%
#W2A15:

# %%
#W2A16:
print('Spring\nSummer\nAutumn\nWinter')
# Out:
# Spring
# Summer
# Autumn
# Winter

# %%
#W2A17:
print('  *')
print(' ***')
print('*****')
# Out:
#   *
#  ***
# *****

# %%
#W2A19:
print('Monday\nTuesday\nWednesday\nThursday\nFriday\nSaturday\nSunday')
# Out:
# Monday
# Tuesday
# Wednesday
# Thursday
# Friday
# Saturday
# Sunday
